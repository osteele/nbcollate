# %% [markdown]
# # Notebook Title
#
# Notebook description.

# %% [markdown]
# ## Question 1
#
# Question 1 text.

# %%
print("Q1 answer A.")
# Out:
# Q1 answer A.

# %% [markdown]
# ## Question 2
#
# Question 2 text.

# %%
print("Q2 answer B.")
# Out:
# Q2 answer A.
