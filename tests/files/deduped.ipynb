# %% [markdown]
# # Notebook Title
#
# Notebook description.

# %% [markdown]
# ## Question 1
#
# Question 1 text.

# %%
print("Q1 answer A.")
# Out:
# Q1 answer A.

# %% [markdown]
# ## Question 2
#
# Question 2 text.

# %% [markdown]
# ## A Quick Poll
#
# In the space below, say something.

# %%
print("Q2 answer B.")
# Out:
# Q2 answer A.

# %%
print("Q2 answer A.")
# Out:
# Q2 answer A.
